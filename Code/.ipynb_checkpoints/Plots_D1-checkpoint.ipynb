# %%
import os
import plotly.express as px
import hvplot.pandas
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
property_df = pd.read_csv("../Data/PropertyTraits.csv")
property_df.head()
# Out:
#    Unnamed: 0  PropertyID  Type State   Price  \
# 0           0  2016723553  Sale   QLD  349000
# 1           1  2016727278  Sale   QLD  140000
# 2           2  2016806859  Sale   QLD  559000
# 3           3  2016834181  Sale   QLD  329000
# 4           4  2016837531  Sale   QLD  384000
#
#                                             Features Bathrooms Bedrooms  \
# 0               ['SwimmingPool', 'Furnished', 'Gym']       1.0      1.0
# 1  ['CableOrSatellite', 'SwimmingPool', 'Furnishe...       1.0       na
# 2  ['AirConditioning', 'BuiltInWardrobes', 'Cable...       2.0      2.0
# 3  ['AirConditioning', 'BuiltInWardrobes', 'Secur...       1.0      1.0
# 4  ['AirConditioning', 'BuiltInWardrobes', 'Gas',...       1.0      1.0
#
#   Carspaces          Area         Suburb Postcode     Latitude   Longitude
# 0         1  City & North  BRISBANE CITY     4000    -27.46224    153.0309
# 1        na  City & North  BRISBANE CITY     4000  -27.4732361   153.02713
# 2         1  City & North  BRISBANE CITY     4000  -27.4705048  153.029892
# 3         1  City & North  BRISBANE CITY     4000    -27.46224    153.0309
# 4         1  City & North  BRISBANE CITY     4000   -27.472084    153.0285

# %%
new_df = property_df[["PropertyID", "Price", "Latitude", "Longitude"]]
new_df.head()
# Out:
#    PropertyID   Price     Latitude   Longitude
# 0  2016723553  349000    -27.46224    153.0309
# 1  2016727278  140000  -27.4732361   153.02713
# 2  2016806859  559000  -27.4705048  153.029892
# 3  2016834181  329000    -27.46224    153.0309
# 4  2016837531  384000   -27.472084    153.0285

# %%
new_df["Latitude"] = new_df["Latitude"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8e4c3b8c542e> in <module>
# ----> 1 new_df["Latitude"] = new_df["Latitude"].astype(int)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     681         # work around NumPy brokenness, #1987
#     682         if np.issubdtype(dtype.type, np.integer):
# --> 683             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     684
#     685         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '-27.46224'

# %%
# Read the Mapbox API key
map_box_api = os.getenv("MAPBOX_API_KEY")

# Set the Mapbox API
px.set_mapbox_access_token(map_box_api)

# %%
plot1 = px.scatter_mapbox(new_df,
                          lat='Latitude',
                          lon='Longitude',
                          color='PropertyID')

plot1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: '-27.46224-27.4732361-27.4705048-27.46224-27.472084-27.4705048-27.46224-27.4623528-27.4719563-27.4626713-27.472681-27.464283-27.4705048-27.465168-27.46295-27.465168-27.47036-27.465168-27.47036-27.4705048-27.4719563-27.4705048-27.4705048-27.4721432-27.4660988-27.4705048-27.472084-27.4717636-27.47036na-27.46262-27.4626026-27.46358-27.315733-27.3012543'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1169                 raise TypeError('Could not convert {value!s} to numeric'
# -> 1170                                 .format(value=x))
#    1171     return x
#
# TypeError: Could not convert -27.46224-27.4732361-27.4705048-27.46224-27.472084-27.4705048-27.46224-27.4623528-27.4719563-27.4626713-27.472681-27.464283-27.4705048-27.465168-27.46295-27.465168-27.47036-27.465168-27.47036-27.4705048-27.4719563-27.4705048-27.4705048-27.4721432-27.4660988-27.4705048-27.472084-27.4717636-27.47036na-27.46262-27.4626026-27.46358-27.315733-27.3012543 to numeric
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: '-27.46224-27.4732361-27.4705048-27.46224-27.472084-27.4705048-27.46224-27.4623528-27.4719563-27.4626713-27.472681-27.464283-27.4705048-27.465168-27.46295-27.465168-27.47036-27.465168-27.47036-27.4705048-27.4719563-27.4705048-27.4705048-27.4721432-27.4660988-27.4705048-27.472084-27.4717636-27.47036na-27.46262-27.4626026-27.46358-27.315733-27.3012543'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9821fbe8f485> in <module>
#       2                           lat='Latitude',
#       3                           lon='Longitude',
# ----> 4                           color='PropertyID')
#       5
#       6 plot1.show()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\plotly\express\_chart_types.py in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1124     symbol mark on a Mapbox map.
#    1125     """
# -> 1126     return make_figure(args=locals(), constructor=go.Scattermapbox)
#    1127
#    1128
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2091     fig._px_trendlines = pd.DataFrame(trendline_rows)
#    2092
# -> 2093     configure_axes(args, constructor, fig, orders)
#    2094     configure_animation_controls(args, constructor, fig)
#    2095     return fig
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\plotly\express\_core.py in configure_axes(args, constructor, fig, orders)
#     535         configurators[c] = configure_cartesian_axes
#     536     if constructor in configurators:
# --> 537         configurators[constructor](args, fig, orders)
#     538
#     539
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\plotly\express\_core.py in configure_mapbox(args, fig, orders)
#     717     if not center and "lat" in args and "lon" in args:
#     718         center = dict(
# --> 719             lat=args["data_frame"][args["lat"]].mean(),
#     720             lon=args["data_frame"][args["lon"]].mean(),
#     721         )
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     128             except Exception:
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#     132                     # we want to transform an object array
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     477         dtype_count = dtype
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#     481     if axis is not None and getattr(the_sum, 'ndim', False):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1168             except Exception:
#    1169                 raise TypeError('Could not convert {value!s} to numeric'
# -> 1170                                 .format(value=x))
#    1171     return x
#    1172
#
# TypeError: Could not convert -27.46224-27.4732361-27.4705048-27.46224-27.472084-27.4705048-27.46224-27.4623528-27.4719563-27.4626713-27.472681-27.464283-27.4705048-27.465168-27.46295-27.465168-27.47036-27.465168-27.47036-27.4705048-27.4719563-27.4705048-27.4705048-27.4721432-27.4660988-27.4705048-27.472084-27.4717636-27.47036na-27.46262-27.4626026-27.46358-27.315733-27.3012543 to numeric
