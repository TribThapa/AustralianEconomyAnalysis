# %%
import pandas as pd

# %%
# Load raw world data file
world_data = pd.read_csv("../Data/RawData/World_data.csv")

# %%
# Check dataframe
world_data.head()
# Out:
#    year        AU_gdp  AU_gdp_growth  AU_goods_export  AU_inflation  \
# 0  1995  3.672164e+11       3.837755     5.330705e+10      4.627767
# 1  1996  4.003027e+11       3.878585     6.051559e+10      2.615385
# 2  1997  4.345680e+11       3.966538     6.496912e+10      0.224888
# 3  1998  3.988991e+11       4.576689     5.584892e+10      0.860135
# 4  1999  3.886082e+11       5.073599     5.602984e+10      1.483129
#
#    AU_net_income  AU_population        CA_gdp  CA_gdp_growth  CA_goods_export  \
# 0  -1.360998e+10     18072000.0  6.040116e+11            NaN     1.929309e+11
# 1  -1.426600e+10     18311000.0  6.285364e+11            NaN     2.048682e+11
# 2  -1.373516e+10     18517000.0  6.549879e+11            NaN     2.184618e+11
# 3  -1.136180e+10     18711000.0  6.339977e+11       2.796542     2.199484e+11
# 4  -1.188279e+10     18926000.0  6.784100e+11       3.970483     2.477141e+11
#
#    ...  KR_goods_export  KR_inflation  KR_net_income  KR_population  \
# ...

# %% [markdown]
# ### Clean World data

# %%
# Extract GDP data
au_vs_world_gdp = world_data[["year", "AU_gdp", "CA_gdp", "CN_gdp", "GB_gdp", "IN_gdp", "JP_gdp", "KR_gdp", "US_gdp"]]

# Remove '_gdp' string
au_vs_world_gdp.columns = au_vs_world_gdp.columns.str.rstrip('_gdp')

# Rename year column
au_vs_world_gdp.rename(columns={'year': "Year"}, inplace=True)

# Drop NAs
au_vs_world_gdp.dropna(inplace=True)

# Save to csv
au_vs_world_gdp.to_csv("../Data/ProcessedData/aus_vs_world_gdp_cleaned.csv")
# Out:
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Extract GDP growth data
au_vs_world_gdp_growth = world_data[["year", "AU_gdp_growth", "CA_gdp_growth", "CN_gdp_growth", "GB_gdp_growth", "IN_gdp_growth", "JP_gdp_growth", "KR_gdp_growth", "US_gdp_growth"]]

# Remove '_gdp_growth' string
au_vs_world_gdp_growth.columns = au_vs_world_gdp_growth.columns.str.strip('gdp_growth')

# Rename year column
au_vs_world_gdp_growth.rename(columns={'yea': "Year"}, inplace=True)

# Drop NAs
au_vs_world_gdp_growth.dropna(inplace=True)

# Save to csv
au_vs_world_gdp_growth.to_csv("../Data/ProcessedData/aus_vs_world_gdp_growth_cleaned.csv")
# Out:
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Extract world_goods_export data
au_vs_world_goods_export = world_data[["year", "AU_goods_export", "CA_goods_export", "CN_goods_export", "GB_goods_export", "IN_goods_export", "JP_goods_export", "KR_goods_export", "US_goods_export"]]

# Remove '_goods_export' string
au_vs_world_goods_export.columns = au_vs_world_goods_export.columns.str.rstrip('_goods_export')

# Rename year column
au_vs_world_goods_export.rename(columns={'yea': "Year"}, inplace=True)

# Drop NAs
au_vs_world_goods_export.dropna(inplace=True)

# Save to csv
au_vs_world_goods_export.to_csv("../Data/ProcessedData/aus_vs_world_goods_export_cleaned.csv")
# Out:
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Extract world_inflation data
au_vs_world_inflation = world_data[["year", "AU_inflation", "CA_inflation", "CN_inflation", "GB_inflation", "IN_inflation", "JP_inflation", "KR_inflation", "US_inflation"]]

# Remove '_inflation' string
au_vs_world_inflation.columns = au_vs_world_inflation.columns.str.rstrip('_inflation')

# Rename year column
au_vs_world_inflation.rename(columns={'year': "Year"}, inplace=True)

# Drop NAs
au_vs_world_inflation.dropna(inplace=True)

# Save to csv
au_vs_world_inflation.to_csv("../Data/ProcessedData/aus_vs_world_inflation_cleaned.csv")
# Out:
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Extract world_population data
au_vs_world_population = world_data[["year", "AU_population", "CA_population", "CN_population", "GB_population", "IN_population", "JP_population", "KR_population", "US_population"]]

# Remove '_population' string
au_vs_world_population.columns = au_vs_world_population.columns.str.rstrip('_population')

# Rename year column
au_vs_world_population.rename(columns={'year': "Year"}, inplace=True)

# Drop NAs
au_vs_world_population.dropna(inplace=True)

# Save to csv
au_vs_world_population.to_csv("../Data/ProcessedData/aus_vs_world_population_cleaned.csv")
# Out:
# C:\Users\TribThapa\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
